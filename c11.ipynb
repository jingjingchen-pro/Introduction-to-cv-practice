# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 256
im = np.zeros((N, N, 3))
for i in range(N):
    im[i, :, 0] = i * 0.0039
    im[i, :, 1] = 1 - i * 0.0039
    im[i, :, 2] = 1

plt.axis('off')
plt.imshow(im);

# %%
0.0039 * 256
# Out:
# 0.9984
